# %% [markdown]
# <a href="https://colab.research.google.com/github/BangleCoding/TIL/blob/main/Python/jupyter_notebook_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
y=7
print(x+y)
print((x + y)*2)
# Out:
# 10
# 20

# %% [markdown]
# # hello world
# ## hello world
# ### hello world
#
# 1. hello world
# 2. hello world
# 3. hello world
#
# - hello world
# -hello world
# -hello world
#
# * hello world
# * hello world
#
# >hello world
#
# hello world *hello* world
